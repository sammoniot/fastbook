# %% [markdown]
# # XQuery in Python: Process a whole collection at once on project XML files
#
# Source: <https://stackoverflow.com/questions/75142854/how-to-use-the-collection-function-with-saxonche>
#
# ## New pip installs
# * For this homework, you'll need to install the **pathlib** library so we can run XQuery across platforms on Mac *and* Windows.
# In your python environment for this series of notebooks, run `pip install pathlib`
# * If you didn't install spacy before, be sure to `pip install spacy`
# * Also, if you didn't download the spacy large language model, uncomment the line to download the spacy large model to your virtual environment.

# %%
# !pip install saxonche
# !pip install pathlib
import os
import pathlib
from pathlib import Path
import spacy
import re as regex
# re lets us work with regular expressions in Python
from saxonche import PySaxonProcessor
from os import getcwd
# this lets us retrieve the current working directory
# Out:
# Requirement already satisfied: saxonche in c:\users\sammo\appdata\local\programs\python\python311\lib\site-packages (12.4.2)
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1

# %% [markdown]
# Remember the spaCy language models? Let's try loading loading the large one to get the maximum amount of information from it!
# There's a lot we can experiment with from spaCy, so here's a link to the documentation for our ready reference:
# <https://spacy.io/usage/spacy-101>
#
# We're going to start by just reviewing its POS (part of speech) and NER (named entity recognition) taggers to see what we can see in your project files.

# %%
# nlp = spacy.cli.download("en_core_web_lg")
# ONLY NEED ABOVE LINE ONCE. REMEMBER: COMMENT OUT THE ABOVE LINE THE NEXT TIME YOU RUN THIS.
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# Okay, let's explore some project files!
# We've loaded the XML directory prepared by the Futurama team for our example here.
#
# * If you have some basic XML right now, like the Futurama team has prepared, we can easily scope in tagged sections of your collection. Swap out the Futurama collection with yours, and adjust the Python code below accordingly.
# * If you don't have XML at this point, you can work around this over text files, or just explore the Futurama collection.

# %%
# DEFINE SOME FILE PATHS FOR INPUT, AND (ONCE WE'RE READY) OUTPUT
InputPath = 'futurama-xml'
OutputPath = 'testOutput'

# %% [markdown]
# The next cell demonstrates the xpath() function, set up to run over individual files.
# Let's look at how it returns information about distinct values of speakers. We're exploring distinct-values() and count() functions here. Try removing them and putting them back to see what the effect of distinct-values() is on the count.

# %%
def readTextFiles(InputPath):
    # This function uses XPath to read the XML input
    for file in os.listdir(InputPath):
        if file.endswith('.xml'):
            filepath = f"{InputPath}/{file}"
            with PySaxonProcessor(license=False) as proc:
                xml = open(filepath, encoding='utf-8').read()
                # ebb: Here we apply the Saxon processor to read files with XPath.
                xp = proc.new_xpath_processor()
                node = proc.parse_xml(xml_text=xml)
                xp.set_context(xdm_item=node)

                # From here on, we select the string that Python will send to NLP. 
                # xpath = xp.evaluate('//your/xpath/here')
                xpath = xp.evaluate('//speak/@who => distinct-values() => sort()')
                count = xp.evaluate('//speak/@who => distinct-values() => count()')
                string = str(xpath)
                print(xpath)
                # xpath is going to go file by file.
             
readTextFiles(InputPath)
# Out:
# "ALIENS"
# "BENDER"
# "BIKE THIEF"
# "BOOTH VOICE"
# "CLARK"
# "CROWD"
# "FARNSWORTH"
# "FRY"
# "IPGEE"
# "KID"
# "LEELA"
# "LOU"
# "MAN"
# "MAN #1"
# "MAN #2"
# "MICHELLE"
# "NIMOY"
# "NIXON"
# "PANUCCI"
# "ROBOT"
# "SMITTY"
# "TERRY"
# "URL"
# "WOMAN"
# "AMY"
# "ANNOUNCER"
# "BENDER"
# "CRATER FACE"
# "CRUSHINATOR"
# "DAISY MAE 128K"
# "EVANS"
# "FANSWORTH"
# "FARMER"
# "FARNSWORTH"
# "FRY"
# "GOPHER #1"
# "GOPHER #2"
# "GOPHERS"
# "HERMES"
# "LEELA"
# "LULABELLE 7"
# "MAN"
# "NARRATOR"
# "RALPH KRAMDENBOT"
# "SAL"
# "WHALERBOT"
# "WHALERBOTS"
# "ZOIDBERG"
# "AMY"
# "ANNOUNCER"
# "BENDER"
# "CALCULON"
# "COMMENTATOR"
# "FARNSWORTH"
# "FRY"
# "HATTIE"
# "HERMES"
# "HUMAN FRIEND"
# "LANDLORD #1"
# "LANDLORD #3"
# "LEELA"
# "MONIQUE"
# "PRIESTBOT"
# "RANDY"
# "SMITTY"
# "TENANT #1"
# "TENANT #2"
# "TENANT #3"
# "URL"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "BOLT"
# "COMPUTER VOICE"
# "CREWMAN"
# "DOUG"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "JANITOR"
# "KIF"
# "LEELA"
# "M-5438"
# "MAN"
# "WOMAN"
# "ZAPP"
# "ZOIDBERG"
# "ANNOUNCER"
# "ARMY ROBOT"
# "BENDER"
# "BENDER FIGURINE"
# "BLUE ELDER"
# "CONSTRUCTIONBOT"
# "ELDERS"
# "FARNSWORTH"
# "FRY"
# "GREEN ELDER"
# "GUARDBOT #1"
# "GUARDBOT #2"
# "HERMES"
# "HOLOHERMES"
# "HUMAN"
# "JUDGE"
# "LEELA"
# "MAN"
# "ORANGE ELDER"
# "PATROL OFFICER #1"
# "PATROL OFFICER #2"
# "RED ELDER"
# "ROBOT"
# "ROBOT #1"
# "ROBOT #2"
# "ROBOT #3"
# "ROBOT #4"
# "ROBOT #5"
# "ROBOT #6"
# "ROBOT #7"
# "ROBOT #8"
# "ROBOT BAILIFF"
# "ROBOT MAYOR"
# "RUSTY"
# "UMPIRE"
# "VENDOR"
# "WENDY"
# "YELLOW ELDER"
# "ZOIDBERG"
# "AMY"
# "ANDERSON"
# "ANNOUNCER"
# "AUCTIONEER"
# "BENDER"
# "BIDDER #1"
# "BIDDER #2"
# "COSMETOLOGIST"
# "DECAPODIAN WOMAN"
# "FARNSWORTH"
# "FRED"
# "FRY"
# "HERMES"
# "IGNER"
# "LARRY"
# "LEELA"
# "MAN"
# "MOM"
# "REPOBOT"
# "ROBOT"
# "ROBOT CHEF"
# "SALESMAN"
# "SALESWOMAN"
# "SMITTY"
# "TEACHER"
# "TELLER"
# "WALT"
# "ZOIDBERG"
# "ALIEN"
# "AMY"
# "BENDER"
# "BONT"
# "CRACK ADDICT"
# "ELZAR"
# "FARNSWORTH"
# "FLORP"
# "FRY"
# "FARNSWORTH"
# "FRY"
# "GLAB"
# "HERMES"
# "HYPERCHICKEN"
# "JUROR #1"
# "JUROR #2"
# "KIF"
# "LEELA"
# "NEPTUNIAN"
# "NEUTRAL PRESIDENT"
# "SMALL GLURMO #1"
# "ZAPP"
# "AMY"
# "ANNOUNCER"
# "BENDER"
# "BUSH SR"
# "CAMPAIGN MANAGER"
# "CARTER"
# "CHANG"
# "CLINTON"
# "CROUPIER"
# "DOLE"
# "FARNSWORTH"
# "FORD"
# "FRY"
# "HERMES"
# "JACKSON"
# "JOHNSON"
# "JOURNALIST #1"
# "LEELA"
# "LINDA"
# "MAN"
# "MINE SPOKESMAN"
# "MORBO"
# "N.R.A. MAN"
# "NARRATOR"
# "NIXON"
# "PAWNBROKER"
# "SCHIFFER"
# "STONED GUY"
# "V.A.P. MAN"
# "WASHINGTON"
# "WOMAN"
# "ZOIDBERG"
# "AMY"
# "ANNOUNCER"
# "BENDER"
# "CHILD"
# "FARNSOWRTH"
# "FARNSWORTH"
# "FRY"
# "HATTIE"
# "HERMES"
# "LEELA"
# "LINDA"
# "MAN"
# "MORBO"
# "O'BRIEN"
# "PREACHERBOT"
# "RAOUL"
# "ROBOT #1"
# "ROBOT #2"
# "ROBOTS"
# "SALESMAN #1"
# "SALESMAN #2"
# "SANTA"
# "TINNY TIM"
# "TREES"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "CROWD"
# "DECAPOD EMPEROR"
# "DECAPOD MAN #1"
# "DECAPOD MAN #2"
# "DECAPOD MANM #1"
# "DECAPOD WOMAN #1"
# "DECAPOD WOMAN #2"
# "DECAPOD WOMAN #3"
# "EDNA"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "LEELA"
# "MAN"
# "NAUTILUS"
# "PLUMBERBOT"
# "RANDY"
# "SINGERS"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "FARNSWORTH"
# "FRY"
# "GARY"
# "HERMES"
# "HOOKERBOT"
# "JUDGE"
# "LEELA"
# "LINCOLN"
# "MALFUNCTIONING EDDIE"
# "MECHANIC"
# "PETUNIA"
# "SAL"
# "SALESMAN"
# "VICTOR"
# "WASHINGTON"
# "WOMAN"
# "ZAPP"
# "ZOIDBERG"
# "ALIEN"
# "AMAZONIAN"
# "AMY"
# "ANNOUNCER"
# "BARKER"
# "BENDER"
# "BENDING UNIT"
# "COWBOY"
# "CRUSHINATOR"
# "EINSTEIN"
# "FARNSWORTH"
# "FLEXO"
# "FRY"
# "HAMMURABI"
# "HERMES"
# "LEELA"
# "MAN"
# "MUGGER"
# "NARRATOR"
# "ROBOT #1"
# "ROBOT #2"
# "ROBOT #3"
# "ROBOT #4"
# "ROBOTS"
# "SMITTY"
# "STOCKBROKER #1"
# "STOCKBROKER #2"
# "STRIPPERBOT"
# "TOUR GUIDE"
# "URL"
# "WOMAN"
# "WOMEN"
# "ZAPP"
# "ZOIDBERG"
# "AMY"
# "ANNOUNCER"
# "BENDER"
# "BILL"
# "BILLIONAIREBOT"
# "CALCULON"
# "CHAIN SMOKER"
# "CHAIR"
# "CLEARCUTTER"
# "COSELL"
# "CROW T"
# "DESTRUCTOR"
# "DOUBLEDEAL"
# "FARNSWORTH"
# "FEMBOT"
# "FEMBOT #1"
# "FLABBY"
# "FNOG"
# "FOREIGNER"
# "FOREMAN"
# "FRY"
# "HATTIE"
# "HERMES"
# "LEELA"
# "LITTLE"
# "MAN #1"
# "MAN #2"
# "MONIQUE"
# "NIXON"
# "REFEREE"
# "REFRESHMENTBOT"
# "ROBOT"
# "ZAPP"
# "ZOIDBERG"
# "5-EYES"
# "ALKAZAR"
# "AMY"
# "BENDER"
# "CYCLOPIAN"
# "CYCLOPS"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "KID"
# "LEELA"
# "MAN"
# "MAN #2"
# "NERD #1"
# "NERD #2"
# "NERD #3"
# "NERD #4"
# "NERDS"
# "PIG"
# "PREACHERBOT"
# "RAT WOMAN"
# "SANDY"
# "SCIENTIST"
# "THING #2"
# "VOICE"
# "YOUNGER KID"
# "ZOIDBERG"
# "AMY"
# "AUSTRALIAN GUY"
# "BENDER"
# "BUREACRATS"
# "EVERYBODY"
# "FARNSWORTH"
# "FRY"
# "GRADE 11"
# "GRADE 20"
# "GRADE 41"
# "GRADE 53"
# "HERMES"
# "IPGEE"
# "LABARBARA"
# "LEELA"
# "LOU"
# "MORGAN"
# "NUMBER 1"
# "OLD MAN"
# "TERRY"
# "WRIST THING"
# "ZOIDBERG"
# "AMY"
# "BARRIERBOT #1"
# "BARRIERBOT #2"
# "BENDER"
# "CUBERT"
# "ELZAR"
# "FARNSWORTH"
# "FRY"
# "GUARDBOT #1"
# "GUARDBOT #2"
# "GUARDBOT #3"
# "GUARDBOT #4"
# "HERMES"
# "HOLOFARNSWORTH"
# "LEELA"
# "MAN #1"
# "MAN #2"
# "UNIVERSAL TRANSLATOR"
# "VERNON"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "COLONEL"
# "DONOVAN"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "LEELA"
# "MERMAID"
# "MERMAIDS"
# "MERMAN"
# "POOPENMEYER"
# "UMBRIEL"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "CLAMPS"
# "COMPUTER VOICE"
# "DOCTOR"
# "DONBOT"
# "ELZAR"
# "FARNSWORTH"
# "FRY"
# "HATTIE"
# "HERMES"
# "JOEY"
# "LEELA"
# "MAN"
# "ROBOT"
# "SMITTY"
# "TINNY TIM"
# "URL"
# "WAITRESS"
# "WOMAN"
# "ZOIDBERG"
# "AMY"
# "ANNOUNCER"
# "BENDER"
# "FARNSWORTH"
# "FRY"
# "FRY AND BENDER"
# "GILLMAN"
# "HERMES"
# "HIPPIE #1"
# "HIPPIE #2"
# "JINGLE"
# "JRRR"
# "KIF"
# "LEELA"
# "LINDA"
# "LRRR"
# "MAN"
# "ND-ND"
# "POPPLER"
# "SMARTLY DRESSED MAN"
# "VENDOR"
# "WAITER"
# "WATERFALL JR"
# "WOMAN"
# "WOMAN #1"
# "WOMAN #2"
# "ZAPP"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "BETAMAX PLAYER"
# "CEILING FAN"
# "COFFEE MACHINE"
# "DESTRUCTOR"
# "FARNSWORTH"
# "FRY"
# "GARBAGE DISPOSAL"
# "GORILLAS"
# "GREETING CARD"
# "HERMES"
# "IGNER"
# "JANITORBOT"
# "LAMP"
# "LARRY"
# "LEELA"
# "LINDA"
# "MAN"
# "MOM"
# "MOM CUT"
# "MORBO"
# "Q.T. MCWHISKERS"
# "ROBOT"
# "ROBOT #1"
# "ROBOT #2"
# "ROBOTS"
# "SLURM MACHINE"
# "TINNY TIM"
# "WALT"
# "WRIST THING"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "CUBERT"
# "DEEP BLUE"
# "FARNSWORTH"
# "FRY"
# "GORE"
# "GYGAX"
# "HAWKING"
# "HERMES"
# "LEELA"
# "NARRATOR"
# "NICHOLS"
# "PANUCCI"
# "SCRUFFY"
# "ZAPP"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "CALCULON"
# "DOCTORBOT"
# "FARNSWORTH"
# "FRY"
# "GYPSY"
# "HERMES"
# "INUITBOT"
# "LEELA"
# "PREACHERBOT"
# "PROJECT SATAN"
# "ROBOT #1"
# "ROBOT #2"
# "ROBOT GHOSTS"
# "SAL"
# "SOLICITORBOT"
# "TANDY"
# "VANDAL #1"
# "VANDAL #2"
# "VLADIMIRGHOST"
# "YOKELBOT"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "BRAIN BALL #1"
# "BRAIN BALL #2"
# "CLERK"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "HICK"
# "IHAWK"
# "KIF"
# "KISSENGER"
# "LEELA"
# "MAN"
# "NIXON"
# "NURSE"
# "P.A. ANNOUNCER"
# "SOLDIER #1"
# "ZAPP"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "BUTCH"
# "CHEF"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "ICE"
# "IPGEE"
# "ITALIAN #1"
# "ITALIAN #2"
# "KID #1"
# "LEELA"
# "MAN"
# "MICHELLE"
# "OLD MAN"
# "OROWHEAT"
# "SAL"
# "SHORE"
# "TERRY"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "LEELA"
# "MAN #1"
# "MAN #2"
# "SAL"
# "SCRUFFY"
# "TRUCKER #1"
# "TRUCKER #2"
# "WAITRESS"
# "WORM GUARD #1"
# "WORM GUARD #2"
# "WORM MAYOR"
# "ZOIDBERG"
# "AMAZONIANS"
# "AMY"
# "BENDER"
# "CHEF"
# "FARNSWORTH"
# "FEMBOT"
# "FEMPUTER"
# "FRY"
# "GUARD #1"
# "GUARD #2"
# "HERMES"
# "KIF"
# "KUG"
# "KUG AND ORNIK"
# "LEELA"
# "MAN"
# "MORBO"
# "OPERATOR"
# "ORNIK"
# "THOG"
# "WOMAN"
# "ZAPP"
# "ZOIDBERG"
# "AMY"
# "ANGLEYNE"
# "AUTOPILOT"
# "BARTENDERBOT"
# "BENDER"
# "CLAMPS"
# "URL"
# "VICTOR"
# "WHITEY"
# "WOMAN"
# "ZOIDBERG"
# "ALL"
# "AMY"
# "ANNOUNCER #1"
# "ANNOUNCER #2"
# "BARMAN"
# "BECK"
# "BENDER"
# "BENDER AND BECK"
# "CATERPILLAR ALIEN"
# "CYLON"
# "CYLON AND GARFUNKEL"
# "DOCTOR"
# "EMCEE"
# "FARNSWORTH"
# "FEMBOT"
# "FRY"
# "GARFUNKEL"
# "HERMES"
# "HIPPIE #1"
# "HIPPIE #2"
# "HIPPIE #3"
# "HIPPIE #4"
# "HIPPIE #5"
# "HIPPIE #6"
# "LEELA"
# "PATCH CORD ADAMS"
# "ROBOT"
# "ROBOT #1"
# "ROBOT #2"
# "ROBOT #3"
# "SAL"
# "ZOIDBERG"
# "ALBERT"
# "ALL"
# "AMY"
# "ARACHNEON"
# "BENDER"
# "CURLY JOE"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "KID"
# "LEELA"
# "LINDA"
# "MAN"
# "NIXON"
# "OLD MAN"
# "PREACHERBOT"
# "SWEET CLYDE"
# "TATE"
# "THORIAS"
# "WHITEY"
# "ZOIDBERG"
# "ALBRIGHTBOT"
# "ALEX"
# "AMY"
# "AUCTIONEER"
# "BENDER"
# "BILLY"
# "CHEECH"
# "FARNSWORTH"
# "FRY"
# "GEORGE MICHAEL"
# "GIRL"
# "HERMES"
# "JERVIS"
# "LEELA"
# "LIU"
# "LIUBOT"
# "LIUBOT #2"
# "LIUBOT #3"
# "LIUBOT #4"
# "MAN"
# "MAVIS"
# "MAYOR"
# "MONROEBOT"
# "MOTHER"
# "NARRATOR"
# "NATALIE"
# "NERD"
# "SAL"
# "SALESMAN"
# "SMITH"
# "TREKKIE #1"
# "TREKKIE #2"
# "VAMPIRE"
# "WOMAN"
# "ZAPP"
# "ZOIDBERG"
# "BENDER"
# "CONSPIRACY NUTTER"
# "DOCTOR #1"
# "DOCTOR #2"
# "ENOS"
# "FARNSWORTH"
# "FRY"
# "GENERAL"
# "LEELA"
# "MAN"
# "MILDRED"
# "SALESMAN"
# "SERGEANT"
# "TRUMAN"
# "ZOIDBERG"
# "ALL"
# "AMY"
# "BAILIFF"
# "BENDER"
# "BOY"
# "CRONKITE"
# "FARNSWORTH"
# "FRY"
# "FRY LEELA AND BENDER"
# "GIRL"
# "HERMES"
# "HYPERCHICKEN"
# "JEFFERY"
# "KWANZAABOT"
# "LEELA"
# "LINDA"
# "MAN"
# "MORBO"
# "MRS GRANT"
# "NEPTUNIAN"
# "NEPTUNIAN #1"
# "NEPTUNIAN #2"
# "NEPTUNIAN #3"
# "NEPTUNIAN #4"
# "NEPTUNIANS"
# "PETUNIA"
# "POOPENMEYER"
# "PRAMALA"
# "ROBOT"
# "ROBOT DEVIL"
# "SANTA"
# "SMITTY"
# "URL"
# "VYOLET"
# "WHITEY"
# "WOMAN"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "BESERK"
# "CUBERT"
# "DONKEY KONG"
# "FARNSWORTH"
# "FRY"
# "GLURMO"
# "HERMES"
# "IGNER"
# "LEELA"
# "LRRR"
# "MAN"
# "MARIO"
# "MOM"
# "NARRATOR"
# "ND-ND"
# "NIXON"
# "PAC"
# "PACMAN"
# "WERNSTRUM"
# "WHO ASK MACHINE"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "ELZAR"
# "FARNSWORTH"
# "FEMBOT #1"
# "FEMBOT #2"
# "FRAME #1"
# "FRAME #2"
# "FRY"
# "GUARD"
# "GWEN"
# "HERMES"
# "LEELA"
# "LIU"
# "LRRR"
# "ND-ND"
# "SHELDON"
# "SHIP"
# "ZOIDBERG"
# "ALBERT"
# "AMY"
# "BENDER"
# "DOCTOR"
# "DWAYNE"
# "FARNSWORTH"
# "FATHER"
# "FRY"
# "GUY"
# "HERMES"
# "HOODED FIGURE #1"
# "HOODED FIGURE #2"
# "KIDS"
# "LEELA"
# "LEG MUTANT"
# "MORRIS"
# "MOTHER"
# "MUNDA"
# "MUTANT"
# "MUTANTS"
# "NINA"
# "OCTOPUS"
# "PHOTOGRAPHER"
# "RAOUL"
# "SMITTY"
# "TRICLOPS"
# "VOGEL"
# "VYOLET"
# "AMY"
# "BENDER"
# "DJ"
# "FARNSWORTH"
# "FRY"
# "HERMES"
# "JOE"
# "KIF"
# "LEELA"
# "MARTIAN"
# "MARTIAN #2"
# "MR WONG"
# "MRS WONG"
# "RJ"
# "SINGING WIND"
# "ZAPP"
# "ZOIDBERG"
# "ALL"
# "AMY"
# "AUSTRALIAN GUY"
# "BENDER"
# "BOY"
# "FARNSWORTH"
# "FRY"
# "HERMENTHOTIP"
# "HERMES"
# "HIGH PRIEST"
# "LEELA"
# "LINDA"
# "MAN #1"
# "MAN #2"
# "MORBO"
# "OSIRAN"
# "PREACHERBOT"
# "PRIEST"
# "PRIESTS"
# "ROLLERSKATER"
# "SAL"
# "SCRUFFY"
# "SINGER"
# "SLAVE #1"
# "SLAVE #2"
# "SLAVE #3"
# "SLAVES"
# "STATUE"
# "WOMAN"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "FARMER #1"
# "FARMER #2"
# "FARNSWORTH"
# "FEMALE VOICE"
# "FRY"
# "GALAXY"
# "GOD"
# "GYPSY"
# "HELPER"
# "HERMES"
# "LEELA"
# "LRRR"
# "MALACHI"
# "MALACHI JR"
# "MONK #1"
# "MONK #2"
# "MONK #3"
# "PIRATE"
# "PRIEST"
# "SALESMAN"
# "SHERPA"
# "SHRIMPKIN PRIEST"
# "SHRIMPKINS"
# "ZOIDBERG"
# "AMY"
# "BENDER"
# "BROKERBOT #1"
# "BROKERBOT #2"
# "BROKERBOT #3"
# "CALCULON"
# "CAVEMAN"
# "ELZAR"
# "EVERYONE"
# "FARNSWORTH"
# "FRY"
# "HATTIE"
# "HERMES"
# "IGNER"
# "JOE"
# "JOR"
# "LACKEY"
# "LEELA"
# "MAN"
# "MOM"
# "MONSTER"
# "NARRATOR"
# "PIG"
# "ROBOT #1"
# "ROBOT #2"
# "SCRUFFY"
# "SUZ"
# "THAT GUY"
# "WALT"
# "ZOIDBERG"
# "AARON JR"
# "GENEWORKS WOMAN"
# "HERMES"
# "HOBO #1"
# "HOBO #2"
# "HOLOROSEANNE"
# "KIF"
# "LEELA"
# "LITTLE ORPHAN"
# "MAN"
# "MOM"
# "MORBO"
# "NIXON"
# "RANDY"
# "SCRUFFY"
# "SMITTY"
# "TATTOO"
# "URL"
# "WHALE BIOLOGIST"
# "WHITEY"
# "WOMAN"
# "ZAPP"
# "ZOIDBERG"
# "ALIEN"
# "AMY"
# "BENDER"
# "FARNSWORTH"
# "FRY"
# "GUARD #1"
# "GUARD #2"
# "HERMES"
# "LEELA"
# "LINDA"
# "LRRR"
# "MAN"
# "MORBO"
# "ND-ND"
# "PETUNIA"
# "RANGER PARK"
# "SAL"
# "SALESMAN"
# "SCIENTIST"
# "ZOIDBERG"
# "AMY"
# "BARBADOS SLIM"
# "BENDER"
# "CALCULON"
# "COILETTE"
# "COMMENTATOR"
# "ELZAR"
# "FARNSWORTH"
# "FEMALE ANNOUNCER"
# "FRY"
# "HEDONISMBOT"
# "HERMES"
# "HUMORBOT 5"
# "HUMOUBOT 5"
# "LABARBARA"
# "LEELA"
# "MALE ANNOUNCER"
# "OFFICIAL"
# "PREACHERBOT"
# "ROBOT"
# "STARTER"
# "ZOIDBERG"
# "AMY"
# "ANNOUNCER"
# "BENDER"
# "CARTRIDGE UNIT"
# "FARNSWORTH"
# "FATBOT"
# "FRY"
# "HERMES"
# "IGNER"
# "LARRY"
# "LEELA"
# "MAN"
# "MOM"
# "NANNYBOT 1"
# "ROBERTO"
# "ROBOT 1"
# "SINCLAIR"
# "TEENBOT"
# "UPGRADER"
# "WATERBOT"
# "WERNSTROM"
# "ZOIDBERG"
# "ALPHABOT"
# "AMY"
# "ANTONIO"
# "BENDER"
# "BETABOT"
# "CALCULON"
# "CASTING DIRECTOR"
# "COOL"
# "CUBERT"
# "DIRECTOR"
# "DWIGHT"
# "EMOTITRON JR"
# "FARNSWORTH"
# "FART MOB"
# "FRY"
# "GAMMABOT"
# "HERMES"
# "HUMAN FRIEND"
# "LEELA"
# "LINDA"
# "MACAULAY CULKON"
# "MOMBOT"
# "MONIQUE"
# "MORBO"
# "NETWORK PRESIDENT"
# "ROBBERBOT"
# "SAL"
# "SECURITY GUARD"
# "TINNY TIM"
# "ZOIDBERG"
# "AMY"
# "ANNOUNCER"
# "BARTENDER"
# "BENDER"
# "CALCULON"
# "FARNSWORTH"
# "FRY"
# "GRUMPY SNAIL"
# "HEDONISMBOT"
# "HERMES"
# "HOLO ROBOT DEVIL"
# "HOLOBENDER"
# "HOLOFRY"
# "HOLOLEELA"
# "HOLOORPHANS"
# "HOLOVOGEL"
# "KID"
# "LEELA"
# "MOTHER"
# "MRS MELLENGER"
# "NIXON"
# "PREACHERBOT"
# "ROBOT DEVIL"
# "SCRUFFY"
# "TINNY TIM"
# "ZAPP"
# "ZOIDBERG"

# %% [markdown]
# ## Introducing XQuery!
# XQuery is what we want to use to help read data from across a whole directory, or "corpus" collection of files.
# XQuery can be written as a separate file (with .xql or .xquery extension) in oXygen over a directory. But we will find it more useful
# to apply it in Python if we're working on natural language processing applications.
#
# ### Setting up XQuery in Python
# We use the same "boilerplate" PySaxonProcessor lines, but switch from xpath to the xquery processor.
#
#
# Requirements:
# * We need all the xq lines to plug this processing into Python. You can use this code as a starter for your projects.
# * The XQuery script is written inside a quoted block in the set_query_content() function that needs to take a quoted string, just like in the cell below.
# * We need the run_query_to_value() function to execuit the script we're writing.
#
#
# **Reading the collection**: We're setting this up to read a `collection()` function, which is a directory of XML files.
# **Writing XQuery**: This involves setting simple variables equal to xpath expressions. XQuery variables are defined with a `$`.
# **XQuery Comments**: look like sideways smiley faces. `(: I'm an XQuery comment :)`
#
# Let's take a look:

# %%
def xqueryOverFiles(InputPath):
    # This time, let's try XQuery over a collection of files:
    with PySaxonProcessor(license=False) as proc:
        print(proc.version)
        xq = proc.new_xquery_processor()
        # This only works on Mac / Linux: xq.set_query_base_uri('file://'+getcwd()+'/')
        xq.set_query_base_uri(Path('.').absolute().as_uri() + '/')
        xq.set_query_content('''
let $futurama := collection('futurama-xml/?select=*.xml')
let $speakers := $futurama//speak/@who => distinct-values() => sort()
let $count := count($speakers)
return $speakers

   (: ebb: I'm writing in an XQuery comment, and pointing out you can define and return any variable you want in the XQuery zone. :)
   (: ebb: Try changing this one to return $speakers instead of the $count variable. :)
   (: ebb: We're writing an query-based syntax called FLWOR (pronounced "flower") and every FLWOR requires a return statement at the end. :)
    
''')
        r = xq.run_query_to_value()
        print(r)  
                               
xqueryOverFiles(InputPath)
# Out:
# SaxonC-HE 12.4.2 from Saxonica
# "5-EYES"
# "AARON JR"
# "AARON SR"
# "AD ROCK"
# "ADLAI"
# "AHAB"
# "AKI"
# "ALBERT"
# "ALBRIGHTBOT"
# "ALEX"
# "ALIEN"
# "ALIENS"
# "ALKAZAR"
# "ALL"
# "ALPHABOT"
# "AMAZONIAN"
# "AMAZONIANS"
# "AMBASSADOR MOIVIN"
# "AMY"
# "AMY 1"
# "AMY 420"
# "ANDERSON"
# "ANDREW"
# "ANDY"
# "ANGLEYNE"
# "ANNOUNCER"
# "ANNOUNCER #1"
# "ANNOUNCER #2"
# "ANTONIO"
# "ARACHNEON"
# "ARMY ROBOT"
# "ARTHUR"
# "ATILLA THE HUN"
# "AUCTIONEER"
# "AUDIENCE"
# "AUSTRALIAN GUY"
# "AUTOPILOT"
# "BABE"
# "BAILIFF"
# "BAILLIF"
# "BARBADOS SLIM"
# "BARKER"
# "BARMAN"
# "BARRIERBOT #1"
# "BARRIERBOT #2"
# "BARTENDER"
# "BARTENDERBOT"
# "BEASTIE BOYS"
# "BECK"
# "BEE"
# "BEELER"
# "BEES"
# "BENDER"
# "BENDER 1"
# "BENDER 1729"
# "BENDER AND BECK"
# "BENDER AND BENDER 1"
# "BENDER FIGURINE"
# "BENDING UNIT"
# "BESERK"
# "BETABOT"
# "BETAMAX PLAYER"
# "BIDDER #1"
# "BIDDER #2"
# "BIG BRAIN"
# "BIG EARED MUTANT"
# "BIG MOUTHED MUTANT"
# "BIKE THIEF"
# "BILL"
# "BILLIONAIREBOT"
# "BILLY"
# "BLUE ELDER"
# "BOLT"
# "BONT"
# "BOOTH VOICE"
# "BOY"
# "BRAIN #1"
# "BRAIN #2"
# "BRAIN #3"
# "BRAIN BALL #1"
# "BRAIN BALL #2"
# "BRET"
# "BROKERBOT #1"
# "BROKERBOT #2"
# "BROKERBOT #3"
# "BUBBLEGUM TATE"
# "BULLY"
# "BUREACRATS"
# "BUSH SR"
# "BUTCH"
# "BUTLER"
# "BUTT TATTOOS"
# "CADDY"
# "CALCULON"
# "CAMERA"
# "CAMPAIGN MANAGER"
# "CAPTAIN"
# "CARD"
# "CARTER"
# "CARTRIDGE UNIT"
# "CASTING DIRECTOR"
# "CATERPILLAR ALIEN"
# "CAVEMAN"
# "CEILING FAN"
# "CHAIN SMOKER"
# "CHAIR"
# "CHANG"
# "CHAZ"
# "CHEECH"
# "CHEF"
# "CHET"
# "CHILD"
# "CHRISSY"
# "CLAMPS"
# "CLARK"
# "CLEARCUTTER"
# "CLERK"
# "CLINTON"
# "COFFEE MACHINE"
# "COILETTE"
# "COLONEL"
# "COMMENTATOR"
# "COMMISSIONER"
# "COMPUTER VOICE"
# "CONGREGATION"
# "CONSPIRACY NUTTER"
# "CONSTRUCTIONBOT"
# "COOL"
# "COSELL"
# "COSMETOLOGIST"
# "COUNTESS"
# "COWBOY"
# "CRACK ADDICT"
# "CRATER FACE"
# "CREWMAN"
# "CRONKITE"
# "CROUPIER"
# "CROW T"
# "CROWD"
# "CRUSHINATOR"
# "CRYOGENISIST"
# "CRYSTAL"
# "CUBERT"
# "CURLY JOE"
# "CUSTOMER"
# "CYCLOPIAN"
# "CYCLOPS"
# "CYGNOID #2"
# "CYGNOID #3"
# "CYGNOID MAN"
# "CYGNOID WOMAN"
# "CYLON"
# "CYLON AND GARFUNKEL"
# "DAISY MAE 128K"
# "DARK WIZARD"
# "DECAPOD EMPEROR"
# "DECAPOD MAN #1"
# "DECAPOD MAN #2"
# "DECAPOD MANM #1"
# "DECAPOD WOMAN #1"
# "DECAPOD WOMAN #2"
# "DECAPOD WOMAN #3"
# "DECAPODIAN MAN"
# "DECAPODIAN WOMAN"
# "DEEP BLUE"
# "DESTRUCTOR"
# "DIRECTOR"
# "DIXIE"
# "DJ"
# "DOCTOR"
# "DOCTOR #1"
# "DOCTOR #2"
# "DOCTORBOT"
# "DOLE"
# "DOLL"
# "DONBOT"
# "DONKEY KONG"
# "DONOVAN"
# "DOORMAN"
# "DOUBLEDEAL"
# "DOUG"
# "DR PERCEPTRON"
# "DWAYNE"
# "DWIGHT"
# "EDNA"
# "EINSTEIN"
# "ELDERS"
# "ELZAR"
# "EMCEE"
# "EMOTITRON JR"
# "ENOS"
# "ENSIGN"
# "EVANS"
# "EVERYBODY"
# "EVERYONE"
# "EVIL LINCOLN"
# "FANSWORTH"
# "FARMER"
# "FARMER #1"
# "FARMER #2"
# "FARNSOWRTH"
# "FARNSWORTH"
# "FARNSWORTH 1"
# "FARNSWORTH 420"
# "FARNSWORTH XVII"
# "FART MOB"
# "FATBOT"
# "FATHER"
# "FEMALE ANNOUNCER"
# "FEMALE SCIENTIST"
# "FEMALE VOICE"
# "FEMBOT"
# "FEMBOT #1"
# "FEMBOT #2"
# "FEMPUTER"
# "FENDER"
# "FIONA"
# "FISHY JOE"
# "FLABBY"
# "FLEXO"
# "FLORP"
# "FNOG"
# "FORD"
# "FOREIGNER"
# "FOREMAN"
# "FOX ANNOUNCER"
# "FRAKES"
# "FRAME #1"
# "FRAME #2"
# "FRANKIE"
# "FRANKLIN"
# "FRATBOT #1"
# "FRATBOT #2"
# "FRATBOT #3"
# "FRED"
# "FRENCH GUY"
# "FRIEDA WATERFALL"
# "FRY"
# "FRY 1"
# "FRY 1729"
# "FRY AND BENDER"
# "FRY AND ZOIDBERG"
# "FRY LEELA AND BENDER"
# "FUTURE FRY"
# "GALAXY"
# "GAMMABOT"
# "GARBAGE DISPOSAL"
# "GARFUNKEL"
# "GARY"
# "GAS"
# "GAY SAILOR"
# "GEARSHIFT"
# "GENERAL"
# "GENEWORKS WOMAN"
# "GEORGE MICHAEL"
# "GIANT BRAIN"
# "GILLMAN"
# "GIRL"
# "GLAB"
# "GLERMO"
# "GLURMO"
# "GOD"
# "GOPHER #1"
# "GOPHER #2"
# "GOPHERS"
# "GORE"
# "GORGAK"
# "GORILLAS"
# "GRADE 11"
# "GRADE 20"
# "GRADE 41"
# "GRADE 53"
# "GREEN ELDER"
# "GREETING CARD"
# "GRUMPY SNAIL"
# "GRUNKA LUNKA #1"
# "GRUNKA LUNKA #2"
# "GRUNKA LUNKAS"
# "GUARD"
# "GUARD #1"
# "GUARD #2"
# "GUARD #3"
# "GUARDBOT #1"
# "GUARDBOT #2"
# "GUARDBOT #3"
# "GUARDBOT #4"
# "GUARDS"
# "GUENTER"
# "GUS"
# "GUY"
# "GUY #1"
# "GUY #2"
# "GWEN"
# "GYGAX"
# "GYPSY"
# "HAIRBOT"
# "HAMMURABI"
# "HATTIE"
# "HAWKING"
# "HEATHER"
# "HEDONISMBOT"
# "HELPER"
# "HERMENTHOTIP"
# "HERMES"
# "HERMES 1"
# "HERMES 25"
# "HICK"
# "HIGH PRIEST"
# "HIPPIE #1"
# "HIPPIE #2"
# "HIPPIE #3"
# "HIPPIE #4"
# "HIPPIE #5"
# "HIPPIE #6"
# "HIROKI"
# "HOBO"
# "HOBO #1"
# "HOBO #2"
# "HOLO ROBOT DEVIL"
# "HOLOBENDER"
# "HOLOFARNSWORTH"
# "HOLOFRY"
# "HOLOHERMES"
# "HOLOLEELA"
# "HOLOORPHANS"
# "HOLOROSEANNE"
# "HOLOVOGEL"
# "HOLOZOIDBERG"
# "HOODED FIGURE #1"
# "HOODED FIGURE #2"
# "HOOKERBOT"
# "HUMAN"
# "HUMAN FRIEND"
# "HUMORBOT 5"
# "HUMOUBOT 5"
# "HUNTER #1"
# "HUNTER #2"
# "HYPERCHICKEN"
# "ICE"
# "IGNER"
# "IHAWK"
# "INFOSPHERE BRAIN"
# "INUITBOT"
# "IPGEE"
# "ITALIAN #1"
# "ITALIAN #2"
# "IZAC"
# "JACK THE RIPPER"
# "JACKIE"
# "JACKSON"
# "JANITOR"
# "JANITORBOT"
# "JEFFERY"
# "JERVIS"
# "JINGLE"
# "JOCKEY"
# "JOE"
# "JOEY"
# "JOHNSON"
# "JOR"
# "JOURNALIST #1"
# "JRRR"
# "JUDGE"
# "JUDGE #1"
# "JUROR #1"
# "JUROR #2"
# "KEGG"
# "KEN"
# "KID"
# "KID #1"
# "KID #2"
# "KID #3"
# "KIDS"
# "KIF"
# "KIRK"
# "KISSENGER"
# "KOENIG"
# "KOJI"
# "KUG"
# "KUG AND ORNIK"
# "KWANZAABOT"
# "LABARBARA"
# "LACKEY"
# "LAMP"
# "LANDLORD #1"
# "LANDLORD #3"
# "LARRY"
# "LEELA"
# "LEELA 1"
# "LEELA 1729"
# "LEG MUTANT"
# "LINCOLN"
# "LINCOLNBOT"
# "LINDA"
# "LITTLE"
# "LITTLE BOY"
# "LITTLE ORPHAN"
# "LIU"
# "LIUBOT"
# "LIUBOT #2"
# "LIUBOT #3"
# "LIUBOT #4"
# "LOU"
# "LRRR"
# "LULABELLE 7"
# "M-5438"
# "MACAULAY CULKON"
# "MAD HATTERBOT"
# "MALACHI"
# "MALACHI JR"
# "MALE ANNOUNCER"
# "MALE SCIENTIST"
# "MALFUNCTIONING EDDIE"
# "MAN"
# "MAN #1"
# "MAN #2"
# "MAN #3"
# "MAN #4"
# "MANDY"
# "MARIO"
# "MARTIAN"
# "MARTIAN #2"
# "MAVIS"
# "MAYOR"
# "MCA"
# "MCNEAL"
# "MECHANIC"
# "MEIDERNEYER"
# "MELLLVAR"
# "MELLLVARS"
# "MERG"
# "MERMAID"
# "MERMAIDS"
# "MERMAN"
# "MIC"
# "MICHELLE"
# "MIDWIFE"
# "MIKE"
# "MILDRED"
# "MILITARY MAN"
# "MINE SPOKESMAN"
# "MOM"
# "MOM CUT"
# "MOMBOT"
# "MONIQUE"
# "MONK #1"
# "MONK #2"
# "MONK #3"
# "MONKEY"
# "MONROEBOT"
# "MONSTER"
# "MOOSE"
# "MORBO"
# "MORGAN"
# "MORIARTY"
# "MORRIS"
# "MOTHER"
# "MR FRY"
# "MR WONG"
# "MRS FRY"
# "MRS GRANT"
# "MRS MELLENGER"
# "MRS WONG"
# "MUGGER"
# "MUNDA"
# "MUTANT"
# "MUTANTS"
# "MYRTLE FU"
# "N.R.A. MAN"
# "NANNYBOT 1"
# "NARRATOR"
# "NATALIE"
# "NAUTILUS"
# "ND-ND"
# "NEPTUNIAN"
# "NEPTUNIAN #1"
# "NEPTUNIAN #2"
# "NEPTUNIAN #3"
# "NEPTUNIAN #4"
# "NEPTUNIANS"
# "NERD"
# "NERD #1"
# "NERD #2"
# "NERD #3"
# "NERD #4"
# "NERDS"
# "NETWORK PRESIDENT"
# "NEUTRAL PRESIDENT"
# "NIBBLER"
# "NIBBLONIAN"
# "NIBBLONIAN CHEF"
# "NICHOLS"
# "NIMOY"
# "NINA"
# "NIXON"
# "NORM"
# "NOTICEABLY F"
# "NUMBER 1"
# "NURSE"
# "NURSE RATCHET"
# "O'BRIEN"
# "O'CONNOR"
# "OCTOPUS"
# "OFFICIAL"
# "OILY"
# "OLD MAN"
# "OLD MAN WATERFALL"
# "OPERATOR"
# "ORANGE ELDER"
# "ORGAN DEALER"
# "ORNIK"
# "OROWHEAT"
# "ORPHAN"
# "OSIRAN"
# "P.A. ANNOUNCER"
# "PAC"
# "PACMAN"
# "PAIN MONSTER"
# "PANUCCI"
# "PARROT"
# "PAST FRY"
# "PATCH CORD ADAMS"
# "PATROL OFFICER #1"
# "PATROL OFFICER #2"
# "PAWNBROKER"
# "PENGUIN #1"
# "PENGUINS"
# "PERSON"
# "PETUNIA"
# "PHOTOGRAPHER"
# "PI-KEA ROBOT"
# "PIG"
# "PIRATE"
# "PLUMBERBOT"
# "POOPENMEYER"
# "POPEIL"
# "POPPLER"
# "PRAMALA"
# "PREACHERBOT"
# "PRIEST"
# "PRIESTBOT"
# "PRIESTS"
# "PROJECT SATAN"
# "PROTESTOR #1"
# "PROTESTOR #2"
# "PROTESTOR #3"
# "PROTOTYPE"
# "Q.T. MCWHISKERS"
# "QUEEN"
# "QUEEQUEG"
# "RALPH KRAMDENBOT"
# "RANDY"
# "RANGER PARK"
# "RAOUL"
# "RAT WOMAN"
# "RAY"
# "RED ELDER"
# "REFEREE"
# "REFRESHMENTBOT"
# "REPOBOT"
# "RICARDO"
# "RIVERS"
# "RJ"
# "ROBBERBOT"
# "ROBERTO"
# "ROBOPUPPY"
# "ROBOT"
# "ROBOT #1"
# "ROBOT #2"
# "ROBOT #3"
# "ROBOT #4"
# "ROBOT #5"
# "ROBOT #6"
# "ROBOT #7"
# "ROBOT #8"
# "ROBOT 1"
# "ROBOT BAILIFF"
# "ROBOT CHEF"
# "ROBOT DEVIL"
# "ROBOT GHOSTS"
# "ROBOT MAYOR"
# "ROBOTS"
# "ROLLERSKATER"
# "RUSTY"
# "SAL"
# "SALESMAN"
# "SALESMAN #1"
# "SALESMAN #2"
# "SALESWOMAN"
# "SALLY"
# "SANDY"
# "SANTA"
# "SCALIA"
# "SCHIFFER"
# "SCIENTIST"
# "SCOOP CHANG"
# "SCOUT LEADER"
# "SCRUFFY"
# "SECURITY GUARD"
# "SERGEANT"
# "SEWERCOM ANNOUNCER"
# "SHATNER"
# "SHELDON"
# "SHERPA"
# "SHIP"
# "SHORE"
# "SHRIMPKIN PRIEST"
# "SHRIMPKINS"
# "SIBLING"
# "SINCLAIR"
# "SINGER"
# "SINGERS"
# "SINGING WIND"
# "SINGLE FEMALE LAWYER"
# "SKIPPER"
# "SLAVE #1"
# "SLAVE #2"
# "SLAVE #3"
# "SLAVES"
# "SLURM ANNOUNCER #2"
# "SLURM MACHINE"
# "SLURM QUEEN"
# "SLURMS"
# "SMALL GLURMO #1"
# "SMALL GLURMO #2"
# "SMARTLY DRESSED MAN"
# "SMITH"
# "SMITTY"
# "SOLDIER #1"
# "SOLICITORBOT"
# "SONG"
# "SOUTER"
# "SPARGLE"
# "STARTER"
# "STATUE"
# "STENOGRAPHER"
# "STEWARD"
# "STEWART"
# "STILT PEOPLE"
# "STOCKBROKER #1"
# "STOCKBROKER #2"
# "STONED GUY"
# "STRIPPERBOT"
# "STUDENT"
# "SUZ"
# "SUZIE"
# "SWEET CLYDE"
# "TAKEI"
# "TANDY"
# "TATE"
# "TATTOO"
# "TEACHER"
# "TECHNICIAN"
# "TEDDY ROOSEVELT"
# "TEENBOT"
# "TELLER"
# "TENANT #1"
# "TENANT #2"
# "TENANT #3"
# "TERRY"
# "THAT GUY"
# "THING #2"
# "THOG"
# "THORIAS"
# "TINNY TIM"
# "TOM SAWYER"
# "TOUR GUIDE"
# "TRASHCAN"
# "TREES"
# "TREKKIE #1"
# "TREKKIE #2"
# "TRICLOPS"
# "TRUCKER #1"
# "TRUCKER #2"
# "TRUMAN"
# "UECKER"
# "UMBRIEL"
# "UMPIRE"
# "UNIT 2013"
# "UNIVERSAL TRANSLATOR"
# "UPGRADER"
# "URL"
# "V.A.P. MAN"
# "VAMPIRE"
# "VAN"
# "VANDAL #1"
# "VANDAL #2"
# "VENDOR"
# "VERNON"
# "VICTOR"
# "VLADIMIRGHOST"
# "VOGEL"
# "VOICE"
# "VYLOET"
# "VYOLET"
# "WAITER"
# "WAITRESS"
# "WALT"
# "WANDA"
# "WASHINGTON"
# "WATERBOT"
# "WATERFALL JR"
# "WATERFALL SR"
# "WELSHY"
# "WENDY"
# "WERNSTROM"
# "WERNSTRUM"
# "WHALE BIOLOGIST"
# "WHALERBOT"
# "WHALERBOTS"
# "WHITEY"
# "WHO ASK MACHINE"
# "WIGGLES"
# "WOMAN"
# "WOMAN #1"
# "WOMAN #2"
# "WOMEN"
# "WORM GUARD #1"
# "WORM GUARD #2"
# "WORM MAYOR"
# "WRIST THING"
# "YANCY"
# "YELLOW ELDER"
# "YOKELBOT"
# "YOUNGER KID"
# "ZAPP"
# "ZOID"
# "ZOIDBERG"
# "ZOIDBERG 1"
# "ZOOKEEPER"

# %% [markdown]
# ## What's the difference?
#
# Notice that you return just one count for the entire collection, not 72 different counts for the speakers in each file.
# How can we use this?
#
# We can get pull information from across the entire collection and find out literally who has the most speeches in the whole series.
# Take a look at this code. Don't worry if you don't know how to write it yet. I just want to show you for demonstration purposes!
# What's here is a nearly full "FLWOR statement" which stands for :
#
# * For
# * Let
# * Where
# * Order by
# * Return
#
# The only things required in a FLWOR statements are L and R. The others give you extra powers like we're seeing here.
#
# **IMPORTANT: You're only allowed one return per FLWOR.**

# %%
def xqueryOverFiles(InputPath):
    # This time, let's try XQuery over a collection of files:
    with PySaxonProcessor(license=False) as proc:
        print(proc.version)
        xq = proc.new_xquery_processor()
        xq.set_query_base_uri(Path('.').absolute().as_uri() + '/')
        xq.set_query_content('''
let $futurama := collection('futurama-xml/?select=*.xml')
let $speakers := $futurama//speak/@who => distinct-values() => sort()
let $count := count($speakers)
for $sp in $speakers
    let $count := $futurama//speak[@who = $sp] => count()
    where $count > 100
    order by $count descending
    return ($sp || ':  ' || $count)
 
''')
        r = xq.run_query_to_value()
        print(r)  
                            

xqueryOverFiles(InputPath)
# Out:
# SaxonC-HE 12.4.2 from Saxonica
# "FRY:  2684"
# "BENDER:  2360"
# "LEELA:  2117"
# "FARNSWORTH:  990"
# "ZOIDBERG:  581"
# "AMY:  499"
# "HERMES:  408"
# "ZAPP:  336"
# "KIF:  197"
# "CALCULON:  114"

# %% [markdown]
# For this notice how we can move **deliberately** in XQuery from information on the whole collection, to information based on individuals in a series.
# The counts we're seeing are NOT based on files, but on info about each speaker!

# %% [markdown]
# ## For statements, measurements, order by, return
#
#
# * Let's choose a character from Futurama who gets a LOT of speeches and use XQuery to pull all their speeches from across the entire collection into one return.
# The next code block is written to show you how to get all the speeches of one character in the WHOLE collection. You can change this to any other character you wish.
# * Let's go through each speech individually and meaasure it:
# * Try out defining a new variable in the XQuery, to use the `string-length()` function, so you can measure the text of the speeches. Try it out!
#
# * We're going to write a for statement so we can evaluate each speech, and order our results based on how long the speeches are,
#      * We'll use the XPath `string-length()` function to measure each speech
#      * We'll work through an XQuery `for` and `order by`
#      * Let's see if we can return the speeches from shortest to longest, then try adding the word `descending` to order them longest to shortest!
#
#
# * YOUR TURN: Edit the code below to return some alternative information!

# %%
def xqueryAndNLP(InputPath):
    # This time, let's try XQuery over a collection of files:
    with PySaxonProcessor(license=False) as proc:
        print(proc.version)
        xq = proc.new_xquery_processor()
        xq.set_query_base_uri(Path('.').absolute().as_uri() + '/')
        xq.set_query_content('''
let $futurama := collection('futurama-xml/?select=*.xml')
let $frySpeeches := $futurama//speak[@who="FRY"]
let $fryTextsOnly := $frySpeeches/text() 
let $fry := for $bt in $fryTextsOnly
   let $length := $bt ! string-length()
   where $length gt 20
   order by $length ascending
   return $bt
return string-join($fry, '\n\n')

''')
        # We started with this: r = xq.run_query_to_value() 
        # If you use this you need to convert r to a string in Python. r = str(run_query_to_value())
        # There's a run_query_to_string() option that's convenient so I'm using it here! 
        r = xq.run_query_to_string()
        #print(r)
    return r
xqueryAndNLP(InputPath)
# Out:
# SaxonC-HE 12.4.2 from Saxonica
# '<?xml version="1.0" encoding="UTF-8"?>\nWhat\'s with the eye?\n\n Last time I checked.\n\n\nWhat does that mean?\n\n\nWhere\'d they all go?\n\n\nOne jillion dollars.\n\n\nJust leave me alone.\n\n\nNo, that\'s not true!\n\n\nHello? Anybody home?\n\n\nThese things happen.\n\n\nLeela! You\'re alive!\n\n\nWhat was your minor?\n\n C\'mon in, \nroomie!  \n\n\nYou know each other?\n\n\nLet\'s put on a show.\n\n\nYou alright, Bender?\n\n Thanks for covering.\n\n\nWhat\'s your problem?\n\n\nShe\'s really strict.\n\n\nTen hundred percent!\n\n\nWow! 2801! Anyway...\n\n\nOh, boy! It\'s Santa!\n\n\nWell check it twice!\n\n\nOh, baby, I\'m there!\n\n\nAw, shucks, Colonel.\n\n\nHey, who\'s this guy?\n\n\nDoes it really work?\n\n\nI love these things!\n\n\nHmm. We lost Bender.\n\n\nIt\'s clovering time!\n\n It worked perfectly!\n\n\nSee you guys Monday!\n\n We\'re not listening!\n\n\nThe fabulous person!\n\n\nYou have to wake up.\n\n\nLeela! You\'re awake!\n\n We don\'t wanna know!\n
# %% [markdown]
# ## Experimenting with some functions
#
#
# Remember how we were going to apply some NLP from spaCy? The next part of this exercise is to take the output of this XQuery function and pass it to the spaCY language model!
#
# We need XQuery in our function above to return just one string if we want to deliver that to spaCY and NLP tools. The way I left this code, it's returning thousands of strings.
#
# * So here's your challenge: Write some code that returns all the text of a different speaker. (Or adjust the code to use in your project.)
# * The `r` variable is storing the XQuery output. I have updated `r` to be xq.run_query_to_string() which should output a single string. If it is not, you can convert it `r` to single string in Python with `str()`.
# * Then make sure it's returning a single string when you print(r). You may need to convert `r`
# * **Write some new code** that delivers this single string to be processed with spaCy in some way.
#     * You can build your code in a new cell block below this one.
#     *  You'll probably want to review [this spaCy NLP assignment](https://github.com/newtfire/textAnalysis-Hub/blob/main/python-nlp-exercise1.md#write-some-python-code-to-do-the-following)
#     * Write your code to return any information of interest from spaCy, following the spaCy documentation as we did in that earlier assignment! Try looking for one or two different kinds of language. What are the most popular verbs, adjectives, nouns? Try out the NER (named entity recognition)...Write your code in your copy of this Jupyter Notebook to complete this exercise.

# %%
Input = xqueryAndNLP(InputPath) 
#print(Input)

Processed = nlp(Input)
FryLemmas=[]    
for  token in Processed:
    if token.pos_ == "VERB": 
        lemma = token.lemma_  
        FryLemmas.append(lemma)    
print (FryLemmas)
# Out:
# SaxonC-HE 12.4.2 from Saxonica
# ['check', 'mean', 'go', 'leave', 'happen', 'know', 'let', 'put', 'cover', 'check', 'work', 'love', 'lose', 'clovere', 'work', 'see', 'listen', 'have', 'wake', 'wanna', 'know', 'move', 'order', 'look', 'understand', 'love', 'preciate', 'have', 'change', 'want', 'pardon', 'excuse', 'get', 'show', 'swallow', 'guess', 'roll', 'move', 'translate', 'have', 'come', 'save', 'think', 'think', 'lose', 'live', 'do', 'wish', 'do', 'dig', 'talk', 'cut', 'get', 'want', 'wake', 'happen', 'do', 'come', 'think', 'look', 'go', 'do', 'call', 'watch', 'get', 'go', 'see', 'mean', 'take', 'say', 'try', 'say', 'let', 'go', 'point', 'see', 'snap', 'think', 'fit', 'listen', 'think', 'happen', 'need', 'cuddle', 'let', 'need', 'look', 'do', 'hear', 'have', 'cry', 'count', 'let', 'open', 'get', 'have', 'hear', 'look', 'want', 'get', 'get', 'look', 'happen', 'have', 'correct', 'talk', 'take', 'see', 'sit', 'bring', 'control', 'get', 'go', 'rescue', 'believe', 'happen', 'lose', 'like', 'taste', 'make', 'go', 'work', 'seem', 'make', 'ask', 'do', 'know', 'forgive', 'give', 'smell', 'call', 'do', 'talk', 'look', 'get', 'go', 'overact', 'go', 'kill', 'hail', 'know', 'ask', 'search', 'let', 'see', 'get', 'get', 'do', 'make', 'think', 'see', 'hug', 'hit', 'get', 'do', 'escape', 'do', 'remember', 'give', 'hurt', 'let', 'go', 'bowl', 'burn', 'have', 'quit', 'stop', 'play', 'have', 'imagine', 'see', 'slow', 'want', 'hate', 'kick', 'know', 'have', 'want', 'have', 'teach', 'say', 'do', 'get', 'regret', 'take', 'happen', 'miss', 'let', 'get', 'hurt', 'spend', 'look', 'tell', 'buy', 'control', 'steal', 'dump', 'come', 'get', 'get', 'sound', 'stand', 'break', 'melt', 'find', 'like', 'get', 'hear', 'stop', 'take', 'have', 'go', 'ring', 'have', 'cry', 'want', 'seem', 'understand', 'go', 'see', 'like', 'haggle', 'want', 'run', 'do', 'know', 'do', 'run', 'dunno', 'love', 'take', 'happen', 'fire', 'work', 'open', 'go', 'have', 'hate', 'do', 'guess', 'go', 'keep', 'go', 'go', 'try', 'escape', 'engineer', 'know', 'ask', 'meet', 'wait', 'come', 'fall', 'come', 'jump', 'like', 'see', 'find', 'wait', 'go', 'come', 'do', 'guess', 'sound', 'exist', 'go', 'do', 'know', 'do', 'object', 'back', 'crush', 'build', 'mean', 'eat', 'get', 'look', 'look', 'tell', 'want', 'get', 'save', 'save', 'save', 'kill', 'say', 'lighten', 'have', 'get', 'work', 'be', 'take', 'go', 'wanna', 'marry', 'look', 'come', 'do', 'hurry', 'wanna', 'see', 'come', 'come', 'love', 'wait', 'say', 'come', 'show', 'go', 'die', 'get', 'say', 'seem', 'ride', 'pick', 'smell', 'know', 'think', 'do', 'pop', 'make', 'cry', 'tend', 'go', 'spin', 'fall', "'", 'get', 'decide', 'work', 'go', 'do', 'come', 'come', 'leave', 'look', 'look', 'be', 'go', 'need', 'drink', 'go', 'try', 'watch', 'get', 'wrap', 'go', 'wait', 'like', 'believe', 'have', 'smell', 'gun', 'get', 'listen', 'get', 'rid', 'meet', 'assist', 'hear', 'like', 'get', 'do', 'play', 'look', 'work', 'go', 'talk', 'hear', 'make', 'happen', 'feel', 'care', 'think', 'stay', 'sound', 'get', 'marry', 'come', 'go', 'take', 'fraternize', 'call', 'know', 'call', 'mean', 'destroy', 'wanna', 'walk', 'see', 'hurt', 'steal', 'let', 'see', 'ask', 'fetch', 'laugh', 'write', 'give', 'start', 'mean', 'sleep', 'want', 'go', 'go', 'drown', 'hurt', 'stop', 'say', 'follow', 'help', 'help', 'help', 'stop', 'explain', 'mind', 'come', 'hurt', 'be', 'celebrate', 'feel', 'maul', 'bone', 'try', 'learn', 'do', 'get', 'do', 'wear', 'like', 'cook', 'keep', 'go', 'get', 'stay', 'eat', 'think', 'make', 'hold', 'go', 'do', 'age', 'see', 'move', 'cure', 'do', 'have', 'let', 'do', 'feel', 'do', 'exist', 'do', 'keep', 'say', 'do', 'believe', 'give', 'get', 'have', 'get', 'tell', 'spend', 'miss', 'have', 'get', 'get', 'find', 'have', 'please', 'take', 'have', 'get', 'belong', 'look', 'look', 'have', 'inspire', 'think', 'look', 'was--', 'change', 'live', 'speak', 'try', 'say', 'talk', 'have', 'brau', 'have', 'wait', 'hire', 'freeze', 'get', 'come', 'let', 'mosey', 'live', 'want', 'get', 'get', 'try', 'lov ...
